# %%
import geopandas as gpd

# %%
import os

# %%
os.getcwd()
# Out:
# '/home/aneta/Documents/Projects/future-roots/api/notebooks'

# %%
roads = gpd.read_file('../../app/data/04-RoadNetwor/komunikacie_plochy.shp')

# %%
roads.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 478 entries, 0 to 477
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OBJECTID    478 non-null    int64
#  1   area        478 non-null    float64
#  2   cesta       478 non-null    object
#  3   OP          478 non-null    int64
#  4   Shape_Leng  478 non-null    float64
#  5   Shape__Are  478 non-null    float64
#  6   Shape__Len  478 non-null    float64
#  7   geometry    477 non-null    geometry
# dtypes: float64(4), geometry(1), int64(2), object(1)
# memory usage: 30.0+ KB

# %%
roads.plot(figsize=[20,30])
# Out:
# <Axes: >
